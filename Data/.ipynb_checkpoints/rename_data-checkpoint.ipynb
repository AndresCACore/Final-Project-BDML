# %%
import glob
import numpy as np
import pandas as pd 
import os
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Rename data

# %%
# BORED
a = glob.glob("/mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/bored/*")
origen = []
for e in range(len(a)):
    origen.append(a[e])
    new = origen[e][:78] + str(e+1) +'.jpg' 
    print(new)
    os.rename(a[e],new)
    print(a[e])
# Out:
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/bored/1.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/bored/0001.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/bored/2.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/bored/0002.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/bored/3.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/bored/0003.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/bored/4.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/bored/0014.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/bored/5.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/bored/0015.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/bored/6.jpg
# ...

# %%
# CLOSED
a = glob.glob("/mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Closed/*")
origen = []
for e in range(len(a)):
    origen.append(a[e])
    new = origen[e][:79] + str(e+1) +'.jpg' 
    print(new)
    os.rename(a[e],new)
# Out:
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Closed/1.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Closed/2.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Closed/3.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Closed/4.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Closed/5.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Closed/6.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Closed/7.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Closed/8.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Closed/9.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Closed/10.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Closed/11.jpg
# ...

# %%
# CLOSED
a = glob.glob("/mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Open/*")
origen = []
for e in range(len(a)):
    origen.append(a[e])
    new = origen[e][:77] + str(e+1) +'.jpg' 
    print(new)
    os.rename(a[e],new)
# Out:
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Open/1.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Open/2.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Open/3.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Open/4.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Open/5.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Open/6.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Open/7.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Open/8.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Open/9.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Open/10.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/Open/11.jpg
# ...

# %%
# DROWSY
a = glob.glob("/mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/drowsy/*")
origen = []
for e in range(len(a)):
    origen.append(a[e])
    new = origen[e][:79] + str(e+1) +'.jpg' 
    print(new)
    os.rename(a[e],new)
# Out:
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/drowsy/1.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/drowsy/2.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/drowsy/3.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/drowsy/4.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/drowsy/5.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/drowsy/6.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/drowsy/7.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/drowsy/8.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/drowsy/9.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/drowsy/10.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/drowsy/11.jpg
# ...

# %%
# NO YAWN
a = glob.glob("/mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/no_yawn/*")
origen = []
for e in range(len(a)):
    origen.append(a[e])
    new = origen[e][:80] + str(e+1) +'.jpg' 
    print(new)
    os.rename(a[e],new)
    print(origen[e])
print(len(new))
# Out:
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/no_yawn/1.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/no_yawn/1.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/no_yawn/2.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/no_yawn/10.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/no_yawn/3.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/no_yawn/100.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/no_yawn/4.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/no_yawn/101.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/no_yawn/5.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/no_yawn/102.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/no_yawn/6.jpg
# ...

# %%
# YAWN
a = glob.glob("/mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/yawn/*")
origen = []
for e in range(len(a)):
    origen.append(a[e])
    #new = origen[e][:77] + str(e+1) +'.jpg' 
    #print(new)
    #os.rename(a[e],new)
    print(origen[e])
print(len(origen))
# Out:
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/yawn/1.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/yawn/10.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/yawn/100.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/yawn/101.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/yawn/102.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/yawn/103.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/yawn/104.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/yawn/105.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/yawn/106.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/yawn/107.jpg
# /mnt/d/Bootcamp Python/Final-Project-BDML/Data/drowsiness-dataset/train/yawn/108.jpg
# ...
